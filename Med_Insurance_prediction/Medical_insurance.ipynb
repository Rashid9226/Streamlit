# %% [markdown]
# ## MEDICAL INSURANCE

# %% [markdown]
# #### LOAD LIBRARIES

# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %% [markdown]
# #### IMPORT DATASET

# %%
df = pd.read_csv('insurance.csv')

# %%
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %% [markdown]
# #### NULL VALUE CHECKING

# %%
df['charges'].unique()
# Out:
# array([16884.924 ,  1725.5523,  4449.462 , ...,  1629.8335,  2007.945 ,
#        29141.3603])

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %% [markdown]
# #### CHECK DUPLICATES

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df=df.drop_duplicates()

# %% [markdown]
# #### SPLIT X AND Y

# %%
x = df.drop('charges', axis=1)

# %%
y = df.charges

# %% [markdown]
# #### ENCODE CATEGORICAL COLUMNS AND SCALE NUMERICAL COLUMNS

# %%
catgrcl_colms= ['sex','smoker','region']
numbr_cols= ['age','bmi','children']

# %%
preprocessor =ColumnTransformer(transformers=[('num', StandardScaler(),numbr_cols),
                                            ('cat', OneHotEncoder(drop='first'), catgrcl_colms)])

x= preprocessor.fit_transform(x)

# %% [markdown]
# #### TRAIN TEST SPLIIT

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

# %% [markdown]
# #### BUILD ANN MODEL

# %%
model = Sequential([
    Dense(64, activation='relu', input_shape = (x_train.shape[1],)),
    Dense(32, activation='relu'),
    Dense(1)])
# Out:
# /opt/anaconda3/lib/python3.12/site-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %% [markdown]
# #### COMPILE MODEL

# %%
model.compile(optimizer='adam', loss='mse',metrics=['mae'])

# %% [markdown]
# #### TRAIN THE MODEL

# %%
history = model.fit(
    x_train,
    y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    verbose=1)
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 291259616.0000 - mae: 12743.2363 - val_loss: 316766464.0000 - val_mae: 12730.2373
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 997us/step - loss: 306837824.0000 - mae: 13154.6289 - val_loss: 316695744.0000 - val_mae: 12727.4766
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 984us/step - loss: 330713952.0000 - mae: 13513.5166 - val_loss: 316537472.0000 - val_mae: 12721.6211
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 304340704.0000 - mae: 13088.3945 - val_loss: 316205504.0000 - val_mae: 12709.8730
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 289955200.0000 - mae: 12632.5508 - val_loss: 315588864.0000 - val_mae: 12688.8652
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 936us/step - loss: 318721312.0000 - mae: 13244.0078 - val_loss: 314571200.0000 - val_mae: 12655.1660
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 292945248.0000 - mae: 12900.9434 - val_loss: 313055296.0000 - val_mae: 12605.9697
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 282749728.0000 - mae: 12535.0898 - val_loss: 310923968.0000 - val_mae: 12537.9053
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 280279616.0000 - mae: 12457.8682 - val_loss: 308121120.0000 - val_mae: 12448.8750
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 291043808.0000 - mae: 12695.5127 - val_loss: 304502208.0000 - val_mae: 12332.9697
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 281408160.0000 - mae: 12331.8936 - val_loss: 300030752.0000 - val_mae: 12190.5049
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 280450944.0000 - mae: 12308.8623 - val_loss: 294690496.0000 - val_mae: 12018.8740
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 291242656.0000 - mae: 12430.6367 - val_loss: 288848096.0000 - val_mae: 11827.7549
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 280591968.0000 - mae: 12229.5791 - val_loss: 282056160.0000 - val_mae: 11602.7783
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 973us/step - loss: 264635248.0000 - mae: 11688.4658 - val_loss: 274111936.0000 - val_mae: 11338.6895
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 942us/step - loss: 237382528.0000 - mae: 10931.7832 - val_loss: 265819488.0000 - val_mae: 11056.4824
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 929us/step - loss: 244083008.0000 - mae: 10995.7949 - val_loss: 257097040.0000 - val_mae: 10750.7617
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 245422928.0000 - mae: 11028.9775 - val_loss: 247197984.0000 - val_mae: 10404.6240
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 221483072.0000 - mae: 10118.3262 - val_loss: 236833152.0000 - val_mae: 10052.7188
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 947us/step - loss:
100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 82974672.0000 - mae: 6840.7505 - val_loss: 88373880.0000 - val_mae: 6452.5923
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 81982176.0000 - mae: 6944.3008 - val_loss: 87556176.0000 - val_mae: 6436.4736
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 81376472.0000 - mae: 6773.0312 - val_loss: 86851960.0000 - val_mae: 6404.9111
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 76513712.0000 - mae: 6725.6108 - val_loss: 85959104.0000 - val_mae: 6401.3301
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 87390496.0000 - mae: 7122.5972 - val_loss: 85139440.0000 - val_mae: 6381.6836
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 71799504.0000 - mae: 6494.2910 - val_loss: 84409120.0000 - val_mae: 6347.7720
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 921us/step - loss: 71275736.0000 - mae: 6489.6841 - val_loss: 83289832.0000 - val_mae: 6347.9043
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 915us/step - loss: 81687968.0000 - mae: 7007.8379 - val_loss: 82208752.0000 - val_mae: 6349.9438
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 934us/step - loss: 79393488.0000 - mae: 6876.6270 - val_loss: 81523000.0000 - val_mae: 6312.6299
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 932us/step - loss: 76533384.0000 - mae: 6766.8857 - val_loss: 80846544.0000 - val_mae: 6271.3135
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 85471608.0000 - mae: 7012.1069 - val_loss: 80188672.0000 - val_mae: 6223.8296
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 76700664.0000 - mae: 6653.9697 - val_loss: 79412280.0000 - val_mae: 6192.4712
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 74858784.0000 - mae: 6699.3638 - val_loss: 78786760.0000 - val_mae: 6147.4048
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 71963760.0000 - mae: 6492.7466 - val_loss: 78071744.0000 - val_mae: 6113.4297
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 953us/step - loss: 75244712.0000 - mae: 6531.7915 - val_loss: 77182360.0000 - val_mae: 6111.7500
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 930us/step - loss: 68321296.0000 - mae: 6270.3301 - val_loss: 76454616.0000 - val_mae: 6078.6455
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 951us/step - loss: 62653692.0000 - mae: 6073.9463 - val_loss: 75888952.0000 - val_mae: 6035.2480
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 941us/step - loss: 74346448.0000 - mae: 6515.3193 - val_loss: 74978736.0000 - val_mae: 6014.7510
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 69588992.0000 - mae: 6332.8120 - val_loss: 74296920.0000 - val_mae: 5987.6792
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 954us/step - loss: 68698936.0000 - mae: 6350.0054 - val_loss: 73532776.0000 - val_mae: 5964.3589
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 75121280.0000 - mae: 6490.9946 - val_loss: 72716160.0000 - val_mae: 5954.4521
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 944us/step - loss: 65240072.0000 - mae: 6166.7007 - val_loss: 71792104.0000 - val_mae: 5947.4634
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 943us/step - loss: 74440120.0000 - mae: 6548.3203 - val_loss: 71088184.0000 - val_mae: 5902.1191
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 922us/step - loss: 66471200.0000 - mae: 6214.5161 - val_loss: 70392840.0000 - val_mae: 5864.4517
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 66542440.0000 - mae: 6246.6777 - val_loss: 69680904.0000 - val_mae: 5829.4624
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 919us/step - loss: 60540248.0000 - mae: 5984.0498 - val_loss: 68917720.0000 - val_mae: 5793.5737
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 917us/step - loss: 64234232.0000 - mae: 6148.7969 - val_loss: 68288288.0000 - val_mae: 5758.3457
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 63738448.0000 - mae: 6166.2632 - val_loss: 67538128.0000 - val_mae: 5723.4741
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 935us/step - loss: 62603776.0000 - mae: 5927.6328 - val_loss: 66893992.0000 - val_mae: 5682.3877
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 924us/step - loss: 59492536.0000 - mae: 5825.8838 - val_loss: 66137476.0000 - val_mae: 5673.6753
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 949us/step - loss: 60995276.0000 - mae: 5842.8120 - val_loss: 65356844.0000 - val_mae: 5658.2915
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 937us/step - loss: 62668232.0000 - mae: 6023.1968 - val_loss: 64606968.0000 - val_mae: 5644.0654
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59584196.0000 - mae: 5975.4639 - val_loss: 64006696.0000 - val_mae: 5598.4141
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 59161640.0000 - mae: 5813.6553 - val_loss: 63287384.0000 - val_mae: 5571.9258
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 927us/step - loss: 65957820.0000 - mae: 6078.3223 - val_loss: 62640388.0000 - val_mae: 5528.5010
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 60515324.0000 - mae: 5753.6016 - val_loss: 61916200.0000 - val_mae: 5504.2505
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 57224304.0000 - mae: 5747.0239 - val_loss: 61369268.0000 - val_mae: 5462.6646
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 56140448.0000 - mae: 5654.5269 - val_loss: 60551780.0000 - val_mae: 5447.0137
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 56425292.0000 - mae: 5637.3467 - val_loss: 59915336.0000 - val_mae: 5421.1255
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 946us/step - loss: 54095132.0000 - mae: 5531.2119 - val_loss: 59277512.0000 - val_mae: 5384.4814
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 55787424.0000 - mae: 5665.3032 - val_loss: 58551124.0000 - val_mae: 5365.7388
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 51756168.0000 - mae: 5288.1792 - val_loss: 57868088.0000 - val_mae: 5338.0273
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 48346704.0000 - mae: 5214.0938 - val_loss: 57264756.0000 - val_mae: 5302.2749
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 938us/step - loss: 54601796.0000 - mae: 5614.9741 - val_loss: 56669404.0000 - val_mae: 5279.2139
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 955us/step - loss: 57099676.0000 - mae: 5556.4272 - val_loss: 56043344.0000 - val_mae: 5251.1875
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 939us/step - loss: 52337624.0000 - mae: 5395.8633 - val_loss: 55309428.0000 - val_mae: 5236.8936
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 933us/step - loss: 45599164.0000 - mae: 5123.3999 - val_loss: 54700204.0000 - val_mae: 5203.3594
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 931us/step - loss: 55279104.0000 - mae: 5602.9028 - val_loss: 53716756.0000 - val_mae: 5214.4951
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 928us/step - loss: 47103632.0000 - mae: 5293.5093 - val_loss: 52966580.0000 - val_mae: 5202.0234
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 940us/step - loss: 45772464.0000 - mae: 5175.5342 - val_loss: 52446508.0000 - val_mae: 5156.8398

# %% [markdown]
# #### EVALUATE MODEL

# %%
loss, mae = model.evaluate(x_test, y_test)
print("Mean Absolute Error:", mae)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 67434592.0000 - mae: 5922.8081
# Mean Absolute Error: 5705.8447265625

# %% [markdown]
# #### MAKE PREDICTION

# %%
pred = model.predict(x_test[:5])
print(pred)
print(y_test[:5].values)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# [[ 8408.124]
#  [ 8191.178]
#  [15347.658]
#  [27118.258]
#  [13084.993]]
# [ 8688.85885  5708.867   11436.73815 38746.3551   4463.2051 ]

# %% [markdown]
# #### MODEL SUMMARY

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 64)             │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 32)             │         2,080 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8,069 (31.52 KB)
#  Trainable params: 2,689 (10.50 KB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 5,380 (21.02 KB)

# %% [markdown]
# #### MODEL SAVING

# %%
model.save('med_ins_Pred.keras')

# %%
x_train.shape[1]
# Out:
# 8

# %%
x_train
# Out:
# array([[-1.15549877, -1.00906256, -0.90923416, ...,  0.        ,
#          0.        ,  0.        ],
#        [-1.29795825, -0.80654334,  0.75035092, ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.91016372,  1.12517847,  0.75035092, ...,  1.        ,
#          0.        ,  0.        ],
#        ...,
#        [-1.36918799, -1.42066033, -0.07944162, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.08705265, -0.43676128,  1.58014347, ...,  0.        ,
#          0.        ,  1.        ],
#        [-0.30074188,  0.85214648,  0.75035092, ...,  0.        ,
#          1.        ,  0.        ]])
